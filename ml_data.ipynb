# %%
import pandas as pd

df = pd.read_csv('./data/ml_ready_real_estate_data.csv')
# display(df)
df['price_per_m2'] = df['price'] / df['habitableSurface']
df.to_csv("./data/ml_ready_real_estate_data_with_price_per_m2.csv", index=False)
display(df)
# Out:
#        bedroomCount  bathroomCount  habitableSurface  toiletCount  postCode  \
# 0               2.0            1.0             100.0          1.0      1040
# 1               4.0            2.0             270.0          3.0      1040
# 2               2.0            1.0              87.0          1.0      1040
# 3               2.0            2.0             104.0          2.0      1040
# 4               1.0            1.0              71.0          1.0      1040
# ...             ...            ...               ...          ...       ...
# 76098           4.0            2.0             242.0          2.0      9990
# 76099           3.0            1.0              94.0          1.0      1090
# 76100           3.0            1.0             113.0          1.0      1853
# 76101           3.0            2.0             111.0          2.0      8434
# 76102           3.0            2.0             132.0          2.0      2610
#
# ...

# %%
import pandas as pd


df = pd.read_csv('./data/cleaned_real_estate_data.csv')
# display(df)
df['price_per_m2'] = round(df['price'] / df['habitableSurface'],0)
df.to_csv("./data/cleaned_real_estate_data.csv_with_price_per_m2.csv", sep='\t', encoding='utf-8', index=False)
display(df['price_per_m2'])
# Out:
# 0        3990.0
# 1        3315.0
# 2        5345.0
# 3        5673.0
# 4        4070.0
#           ...
# 76098    2682.0
# 76099    2968.0
# 76100    2646.0
# 76101    2928.0
# 76102    2576.0
# Name: price_per_m2, Length: 76103, dtype: float64

# %%
df = pd.read_csv("./data/cleaned_real_estate_data.csv_with_price_per_m2.csv")
postcode_region_map = df[]
